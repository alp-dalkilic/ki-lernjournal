# %%
type(42)
# Out:
# int

# %%
type(42.0)
# Out:
# float

# %%
type('Alp ist der Größte' * 5)
# Out:
# str

# %%
print('Alp ist der Älteste')
print(str(10 **2) + ' echt so viel?')
alter = 54
print('Nein, so alt auch wieder nicht. Ich bin ' + str(alter) + ' Jahre alt')
# Out:
# Alp ist der Älteste
# 100 echt so viel?
# Nein, so alt auch wieder nicht. Ich bin 54 Jahre alt

# %%
spam = True
spam
# Out:
# True

# %%
42 == 43
# Out:
# False

# %%
42 == 42
# Out:
# True

# %%
2 != 3
# Out:
# True

# %%
'Alp' == 'Alp'
# Out:
# True

# %%
'Alp' == 'Allp'
# Out:
# False

# %%
name = 'Alice'
if name == 'Alices':
  print('Hi, Alice.')
else:
  print('Hello Stranger, what are you doing here')
# Out:
# Hello Stranger, what are you doing here
