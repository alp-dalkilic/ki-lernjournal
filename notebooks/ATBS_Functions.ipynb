# %%
def hello():
    # Prints three greetings
    print("Good morning!")
    print("Good afternoon")
    print("Good evening")

hello()
hello()
print("One more time!")
hello()

# %%
def say_hello_to(name):
    # Prints three greetings to the name provided
    print("Good morning, " + name)
    print("Good afternoon, " + name)
    print("Good evening, " + name)

say_hello_to("Alice")
say_hello_to("Bob")

# %%
# Magic8Ball
import random

def get_answer(answer_number):
    # Returns a fortune answer based on what int answer_number is, 1 to 9
    if answer_number == 1:
        return "It is certain"
    elif answer_number == 2:
        return "It is decidedly so"
    elif answer_number == 3:
        return "Yes"
    elif answer_number == 4:
        return "Reply hazy try again"
    elif answer_number == 5:
        return "Ask again later"
    elif answer_number == 6:
        return "Concentrate and ask again"
    elif answer_number == 7:
        return "My reply is no"
    elif answer_number == 8:
        return "Outlook not so good"
    elif answer_number == 9:
        return "Very doubtful"
    
print("Ask a yes or no question:")
input(">")
r = random.randint(1, 9)
fortune = get_answer(r)
print(fortune)

# %%
# None value
spam = print("Hello")
None == spam

# %%
# Coinflip - alle Outputs werden in eine Zeile geschrieben und nicht jgeweils ein Eintrag in 100 Zeilen
import random
for i in range(100): # Perform 100 coin flips
    if random.randint(0, 1) == 0:
        print("H", end=" ")
    else:
        print("T", end=" ")
print() # Print one newline at the end

# %%
# abcdCallStack
def a():
    print("a() starts")
    b()
    d()
    print("a() returns")

def b():
    print("b() starts")
    c()
    print("b() returns")

def c():
    print("c() starts")
    print("c() returns")

def d():
    print("d() starts")
    print("d() returns")

a()

# %%
def spam():
    eggs = "SpamSpam"
    bacon()
    print(eggs)

def bacon():
    ham = "HamHam"
    eggs = "BaconBacon"

spam() # Es wird nur SpamSpam ausgegeben, da nur die lokale Variable eggs aus spam() exisitiert

# %%
def spam():
    print(eggs)
eggs = "GlobalGlobal"
spam()
print(eggs)

# %%
# same name
def spam():
    eggs = "spam local"
    print(eggs) # Print "spam local"

def bacon():
    eggs = "bacon local" # Print "bacon local"
    print(eggs)
    spam()
    print(eggs) # Print "bacon local"

eggs = "global"
bacon()
print(eggs) # Print "global" i.e. erst wird die funktione bacon() ausgeführt inklusve dem spam() abruf und zuletzt global...

# %%
def spam():
    global eggs
    eggs = "spam_test"

eggs = "global"
spam()
print(eggs)

# %%
def spam():
    global eggs
    eggs = "spam" # This ist the global variable

def bacon():
    eggs = "bacon" # this is a local variable

def ham():
    print(eggs) # this is the global variable

eggs = "global" # this is the global variable
spam()
print(eggs)
# Out:
# spam

# %%
# Error because a local variable is tried to be used globally
def spam():
    eggs12 = "test3"
    print(eggs12)

print(eggs12)
spam()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 6
#       3     eggs12 = "test3"
#       4     print(eggs12)
# ----> 6 print(eggs12)
#       7 spam()
#
# NameError: name 'eggs12' is not defined

# %%
# zeroDevide
def spam(divide_by):
    try:
        #Any code in this block that casues ZeroDivisionError will not crash the programm
        return 42 / divide_by
    except ZeroDivisionError:
        # If ZeroDivisonError happended the code in this block runs:
        print("Error: Invalid argument.")

print(spam(2))
print(spam(12))
print(spam(0))
print(spam(1))
# Out:
# 21.0
# 3.5
# Error: Invalid argument.
# None
# 42.0

# %%
# zeroDevide # Stopt nach dem endeckten Fehler vs. oben: geht die ganzen prints durch
def spam(divide_by):
    return 42 / divide_by
            
try:
    print(spam(2))
    print(spam(12))
    print(spam(0))
    print(spam(1))
except ZeroDivisionError:
    print("Error: Invalid argument.")
# Out:
# 21.0
# 3.5
# Error: Invalid argument.

# %%
# zigzag
import time, sys
indent = 0 # How many spaces to indent
indent_increasing = True # Whether the indentation is increasing or not

try:
    while True: # The main program loop
        print("   " * indent, end=" ")
        print("********")
        time.sleep(0.1) # Pause for 1/10th of a second

        if indent_increasing:
            # Increase the number of spaces:
            indent = indent + 1
            if indent ==5:
                # Change direction:
                indent_increasing = False

        else:
            # Decrease the number of spaces:
            indent = indent - 1
            if indent == 0:
                # Change direction:
                indent_increasing = True

except KeyboardInterrupt:
    sys.exit()

# %%
# Program: Spike
import time, sys
try:
    while True: # the main program loop
        # Draw lines with increasing length:
        for i in range(1, 9):
            print("-" * (i * i))
            time.sleep(0.2)

        # Draw lines with decreasing length:
        for i in range(7, 1, -1):
            print("-" * (i * i))
            time.sleep(0.2)
except KeyboardInterrupt:
    sys.exit()

# %%
# Uebung 1 - Rechteckfläche
def rect_area(b, h):
    return b * h

print(rect_area(3, 4))
print(rect_area(12.5, 2))
# Out:
# 12
# 25.0

# %%
#Uebung 2 - Begrüßung mit Default
def greet(name, greeting="Hallo"):
    print(greeting + ", " + name + "!")
    
greet("Alp")
greet("Alp", greeting = "Servus")
# Out:
# Hallo, Alp!
# Servus, Alp!

# %%
# Uebung 3 - Scope-Beobachtung
counter = 0
def increment():
    for i in range(1, 4):
        global counter
        counter = counter + 1
    print(str(counter))
increment()
# Out:
# 3

# %%
# Uebung 4 - Sichere Zahleneingabe
def ask_int(prompt):
    try:
        print(prompt)
        eingabe = input(">")
        if int(eingabe):
            print(eingabe + " correct")
    except ValueError:
        print("Geben sie bitte eine ganze Zahl ohne Kommastellen ein")
ask_int("Geben sie eine ganze Zahl ein:")
# Out:
# Geben sie eine ganze Zahl ein:
# Geben sie bitte eine ganze Zahl ohne Kommastellen ein

# %%
# Uebung 5 - Fakultäten prüfen 5 (120) und Null (1)
def fact(n):
    ergebnis = 1
    for i in range(1, n+1):
        ergebnis = ergebnis * i
    print(ergebnis)

fact(0)
# Out:
# 1

# %%
# Uebung 6 - Vorzeichen
def sign(x):
    if 0 > x:
        return -1
    elif x == 0:
        return 0
    else:
        return 1
print(sign(-7),sign(0), sign(42))
# Out:
# -1 0 1

# %%
# Collatz-Sequenz als Funktion
def collatz(number):
        while number != 1:
            if number % 2 == 0:
                number = number // 2
            else:
                number = 3 * number + 1
            print(number)
try:
    zahl = int(input(">"))
    collatz(zahl)
except ValueError:
    print("Geben sie eine Ganzzahl ein!")

# %%
# Guess the number game
import random
secret_number = random.randint(1, 20)
print("I am thinking of a number between 1 and 20 and you have 6 attempts to guess it. I just say too high or too low")

for taken_guesses in range(1, 7):
    print("Take a guess")
    guess = int(input('>>'))
    if guess > secret_number:
        print(str(guess) + " is too high")
    elif guess < secret_number:
        print(str(guess) + " is too low")
    else:
        break
if guess == secret_number:
    print(str(guess) + " was my number, very well - you got it right with " + str(taken_guesses) + " attempts")
else:
    print("Maybe next time you read my mind properly. My number was: " + str(secret_number))

# %%
# Guess the number game with functions
import random
secret_number = random.randint(1, 20)
print("I am thinking of a number between 1 and 20 and you have 6 attempts to guess it. I just say too high or too low")

def take_guess():
    print("Take a guess")
    guess = int(input(">"))
    if guess == secret_number:
        print("Congratulation")
        return True
    elif guess > secret_number:
        print("Too high")
        return False
    else:
        print("Too low")
        return False

for i in range(1, 7):
    if take_guess():
        break
# Keine gute Lösung, da mein Code länger und nicht viel einfacher ist als der ohne Funktionen!
# Out:
# I am thinking of a number between 1 and 20 and you have 6 attempts to guess it. I just say too high or too low
# Take a guess
# Too low
# Take a guess
# Too low
# Take a guess
# Too low
# Take a guess
# Too low
# Take a guess
# Too low
# Take a guess
# Too low
